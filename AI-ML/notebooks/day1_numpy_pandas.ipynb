# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print("Setup OK ✅")
# Out:
# Setup OK ✅

# %%
arr = np.array([10,20,30,40])

print("Array:", arr)
print("Mean:", arr.mean())
# Out:
# Array: [10 20 30 40]
# Mean: 25.0

# %%
df = pd.DataFrame({
    "course":["Fullstack","ML","NLP","CV"],
    "hours":[2,2,1,1]
})

df
# Out:
#       course  hours
# 0  Fullstack      2
# 1         ML      2
# 2        NLP      1
# 3         CV      1

# %%
plt.bar(df["course"], df["hours"])
plt.title("Daily Study Plan")
plt.show()
