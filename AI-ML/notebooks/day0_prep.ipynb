# %%
name = "Hemaa"
age = 28

print("Name:", name)
print("Age:", age)

numbers = [10,20,30,40] #list

for n in numbers: #loop
    print(n)

def square(x): #function
    return x*x

print(square(5))
# Out:
# Name: Hemaa
# Age: 28
# 10
# 20
# 30
# 40
# 25
